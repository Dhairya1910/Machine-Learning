# %%
from textblob import TextBlob
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
import yfinance as yf
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# **simple function using textblob that analysis the sentiments of a sentence**

# %%
def analyze_sentiment(text):
  analysis = TextBlob(text)
  if analysis.sentiment.polarity > 0:
    print(analysis.sentiment.polarity)
    return "Positive"
  elif analysis.sentiment.polarity < 0:
    print(analysis.sentiment.polarity)
    return "Negative"
  else:
    return "Netural"

# %% [markdown]
# **function that preprocess the text removing all the useless stuff from the text**

# %%
def text_preprocess(text):
  text = re.sub(r"http\S+|@\S+|#\S+|\d+","",text)
  text = re.sub(r"[^A-Za-z\s]","",text)
  text = text.lower()
  words = word_tokenize(text)
  stop_words = set(stopwords.words("english"))
  filtered_words = [word for word in words if word not in stop_words]
  return " ".join(filtered_words)

# %%
txt = "Suzlon Energy Ltd shares also settled in the red on Friday at ₹55.59 apiece, down 3.99%, on the NSE amid a sluggish trend in the broader market.The stock dropped 10.3% this week, while trading in the red in four of the five sessions.On Monday, the stock had hit the 5% lower circuit. The company clarified in an exchange filing that there was no event or information which triggered the price movement in Monday's session"
# Out:
# -0.051851851851851864
# Negative

# %%
# %time text_preprocess("Suzlon Energy Receives 'Hold' Rating Amid Strong Profit Growth and Management Challenges")
# Out:
# CPU times: user 36 ms, sys: 3.12 ms, total: 39.1 ms
# Wall time: 49.7 ms
# 'suzlon energy receives hold rating amid strong profit growth management challenges'

# %%
# %time analyze_sentiment("Suzlon Energy Receives 'Hold' Rating Amid Strong Profit Growth and Management Challenges")
# Out:
# 0.4333333333333333
# CPU times: user 63.2 ms, sys: 6.15 ms, total: 69.3 ms
# Wall time: 132 ms
# 'Positive'

# %%
df = yf.Ticker("SUZLON.NS")
df = df.history("1y")
print(df)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-01-23 00:00:00+05:30  42.500000  43.000000  40.200001  41.150002
# 2024-01-24 00:00:00+05:30  41.599998  41.599998  40.349998  41.200001
# 2024-01-25 00:00:00+05:30  41.650002  43.000000  40.900002  42.549999
# 2024-01-29 00:00:00+05:30  43.000000  43.849998  42.549999  43.250000
# 2024-01-30 00:00:00+05:30  43.500000  44.849998  42.750000  43.799999
# ...                              ...        ...        ...        ...
# 2025-01-14 00:00:00+05:30  55.200001  57.169998  55.110001  57.169998
# 2025-01-15 00:00:00+05:30  57.169998  59.799999  56.810001  57.259998
# 2025-01-16 00:00:00+05:30  58.759998  59.189999  56.700001  56.869999
# 2025-01-17 00:00:00+05:30  57.000000  57.389999  55.939999  56.840000
# 2025-01-20 00:00:00+05:30  57.520000  57.799999  56.380001  56.740002
#
#                              Volume  Dividends  Stock Splits
# Date
# ...
